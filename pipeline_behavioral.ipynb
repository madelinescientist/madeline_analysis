# %% [markdown]
# ## Opening File

# %%
from behavior_base import *

# %%
import h5py
hfile = h5py.File("C:/Users/right/Desktop/lab/raw data/behavioral/JUV011-211215-gonogo.mat", 'r')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-df9a01f00770> in <module>
# ----> 1 hfile = h5py.File("C:/Users/right/Desktop/lab/raw data/behavioral/JUV011-211215-gonogo.mat", 'r')
#
# D:\Programs\anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# D:\Programs\anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
# ...

# %%
import scipy.io
mat = scipy.io.loadmat("C:/Users/right/Desktop/lab/raw data/behavioral/JUV011-211215-gonogo.mat")

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'exper', '__function_workspace__'])

# %%
mat['__header__']
# Out:
# b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Dec 15 16:04:01 2021'

# %%
len(mat['exper'][0][0])
# Out:
# 3

# %%
mat['exper'][0][0]
# Out:
# (array([[(array([[(array([[(array(['priority'], dtype='<U8'), array(['param'], dtype='<U5'), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=uint8), array([], shape=(0, 0), dtype=object), array([], dtype='<U1'), array([], dtype='<U1'), array([[-1]], dtype=int16), array([[0]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=uint8))]],
#                       dtype=[('name', 'O'), ('type', 'O'), ('value', 'O'), ('range', 'O'), ('list', 'O'), ('format', 'O'), ('ui', 'O'), ('h', 'O'), ('save', 'O'), ('pref', 'O'), ('trial', 'O')]), array([[(array(['dependents'], dtype='<U10'), array(['param'], dtype='<U5'), array([[1]], dtype=uint8), array([[1, 2]], dtype=uint8), array([[array(['rpbox'], dtype='<U5'),
# ...
